# %% [markdown]
# Assignment -01

# %%
message="We all will Data Sceintist on day"
message
# Out:
# 'We all will Data Sceintist on day'

# %%
M1 = "Data Analysis is easy than Data Scenice"
print(M1)
M1="Machine learning would be more difficult"
print(M1)
# Out:
# Data Analysis is easy than Data Scenice
# Machine learning would be more difficult

# %%
name="Mohit"
res="Hello %a , would you like to learn some Python today?" %name
print(res)
name="Mohit"
res=f"Hello {name} , would you like to learn some Python today?"
print(res)
# Out:
# Hello 'Mohit' , would you like to learn some Python today?
# Hello Mohit , would you like to learn some Python today?

# %%
print("Albert Einstein once said" + ' "' + "A person who never made a mistake never tried anything new." +'"' )
# Out:
# Albert Einstein once said "A person who never made a mistake never tried anything new."

# %%
famous_person="Albert Einstein "
quote = "once said \" A person who never made a mistake never tried anything new.\" "
print(famous_person  + quote )
# Out:
# Albert Einstein once said " A person who never made a mistake never tried anything new."

# %%
print(5+3)
print(12-4)
print(2*4)
print(32/4)
# Out:
# 8
# 8
# 8
# 8.0

# %%
fav_num=6
print("Enter your favourite Number " + str(fav_num) )
# Out:
# Enter your favourite Number 6

# %%
famous_person="Albert Einstein " # storing name in a variable
quote = "once said \" A person who never made a mistake never tried anything new.\" " 
print(famous_person  + quote ) # printing a single line with 2 variables
# Out:
# Albert Einstein once said " A person who never made a mistake never tried anything new."

# %%
friends=['mohit','varun','om','ashu','sahi']
print(friends[0])
print(friends[1])
print(friends[2])
print(friends[3])
print(friends[4])
# Out:
# mohit
# varun
# om
# ashu
# sahi

# %%
for message in friends:
    print("Hi i am your friend My name is " +message,end =' ')
# Out:
# Hi i am your friend My name is mohit Hi i am your friend My name is varun Hi i am your friend My name is om Hi i am your friend My name is ashu Hi i am your friend My name is sahi

# %%
listofbike=['Hunter 350','R15','FZ','XSR 155']
for a in listofbike:
    print(f"I would like to ride a {a} motorcycle ")
#print(f"I would like to ride a {', '.join(listofbike)} motorcycle")
# Out:
# I would like to ride a Hunter 350 motorcycle
# I would like to ride a R15 motorcycle
# I would like to ride a FZ motorcycle
# I would like to ride a XSR 155 motorcycle

# %%
listofbike.index('R15')
# Out:
# 1
